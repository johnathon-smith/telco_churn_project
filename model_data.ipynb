# %% [markdown]
# ## Model Data

# %% [markdown]
# ### Acquire the Data

# %%
import numpy as np
import pandas as pd
import acquire
import prepare
from sklearn.ensemble import RandomForestClassifier
from sklearn.dummy import DummyClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
telco = acquire.get_telco_data()
telco.head()
# Out:
#   customer_id  gender  senior_citizen partner dependents  tenure  \
# 0  0016-QLJIS  Female               0     Yes        Yes      65
# 1  0017-DINOC    Male               0      No         No      54
# 2  0019-GFNTW  Female               0      No         No      56
# 3  0056-EPFBG    Male               0     Yes        Yes      20
# 4  0078-XZMHT    Male               0     Yes         No      72
#
#   phone_service    multiple_lines  internet_service_type_id online_security  \
# 0           Yes               Yes                         1             Yes
# 1            No  No phone service                         1             Yes
# 2            No  No phone service                         1             Yes
# 3            No  No phone service                         1             Yes
# 4           Yes               Yes                         1              No
#
#    ... payment_type_id monthly_charges total_charges churn contract_type_id.1  \
# 0  ...               2           90.45        5957.9    No                  3
# 1  ...               4           45.20       2460.55    No                  3
# 2  ...               3           45.05        2560.1    No                  3
# 3  ...               4           39.40         825.4    No                  3
# 4  ...               3           85.15        6316.2    No                  3
#
#    contract_type internet_service_type_id.1  internet_service_type  \
# 0       Two year                          1                    DSL
# 1       Two year                          1                    DSL
# 2       Two year                          1                    DSL
# 3       Two year                          1                    DSL
# 4       Two year                          1                    DSL
#
#    payment_type_id.1               payment_type
# 0                  2               Mailed check
# 1                  4    Credit card (automatic)
# 2                  3  Bank transfer (automatic)
# 3                  4    Credit card (automatic)
# 4                  3  Bank transfer (automatic)
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Prepare the Data

# %%
train, validate, test = prepare.prep_with_encoding(telco)

# %%
#Split into X and y groups
X_train, y_train = train.drop('churn', axis = 1), train.churn
X_validate, y_validate = validate.drop('churn', axis = 1), validate.churn
X_test, y_test = test.drop('churn', axis = 1), test.churn

# %% [markdown]
# ### Set Baseline Accuracy

# %%
#I will use the most common entry as the baseline for predicting churn.
#What is the most common value?
train.churn.value_counts()
# Out:
# 0    2891
# 1    1046
# Name: churn, dtype: int64

# %%
#The most common entry is 0, or False for churn.
baseline = DummyClassifier(strategy = 'constant', constant = 0)
baseline.fit(X_train, y_train)
baseline.score(X_train, y_train)
# Out:
# 0.7343154686309372

# %% [markdown]
# #### Baseline accuracy in training data set is about 73%.

# %% [markdown]
# ### Random Forest Classifiers
# I will use a Random Forest Classifier for my MVP. To find the best version, I will loop through 25 different values for max_depth and find the one that has the best accuracy.

# %%
model_dicts = []

for num in range(1, 26):
    #Instantiate new model
    clf = RandomForestClassifier(random_state = 123, max_depth = num)
    
    #Fit the model
    clf.fit(X_train, y_train)
    
    #Score the model on training data
    train_score = clf.score(X_train, y_train)
    
    #Make predictions on validate data to use in confusion matrix
    clf_preds = clf.predict(X_validate)
    
    #Use confusion matrix to find TP, FP, TN, FN
    tp = confusion_matrix(y_validate, clf_preds)[1][1]
    fp = confusion_matrix(y_validate, clf_preds)[0][1]
    tn = confusion_matrix(y_validate, clf_preds)[0][0]
    fn = confusion_matrix(y_validate, clf_preds)[1][0]
    #Score the model on validate data
    validate_score = clf.score(X_validate, y_validate)
    
    #Create a dictionary for model values
    output = {
        'max_depth':num,
        'True Positves': tp,
        'False Positives': fp,
        'True Negatives': tn,
        'False Negatvies': fn,
        'Precision': tp / (tp + fp),
        'Recall': tp / (tp + fn),
        'Training Score': train_score,
        'Validate Score': validate_score,
        'Score Difference': train_score - validate_score
    }
    
    model_dicts.append(output)

#Print out all the info in a dataframe
models = pd.DataFrame(model_dicts)
# Out:
# <ipython-input-7-1ade3c6878ad>:31: RuntimeWarning: invalid value encountered in long_scalars
#   'Precision': tp / (tp + fp),

# %%
models
# Out:
#     max_depth  True Positves  False Positives  True Negatives  \
# 0           1              0                0            1239
# 1           2             39                7            1232
# 2           3            132               57            1182
# 3           4            167               72            1167
# 4           5            197               87            1152
# 5           6            197               92            1147
# 6           7            213              104            1135
# 7           8            215              113            1126
# 8           9            223              117            1122
# 9          10            225              124            1115
# 10         11            227              128            1111
# 11         12            222              131            1108
# 12         13            227              137            1102
# 13         14            227              140            1099
# 14         15            227              140            1099
# 15         16            221              145            1094
# 16         17            220              142            1097
# 17         18            223              144            1095
# 18         19            223              131            1108
# 19         20            225              136            1103
# 20         21            223              138            1101
# 21         22            218              138            1101
# 22         23            216              136            1103
# 23         24            216              144            1095
# 24         25            218              145            1094
#
#     False Negatvies  Precision    Recall  Training Score  Validate Score  \
# 0               449        NaN  0.000000        0.734315        0.734005
# 1               410   0.847826  0.086860        0.753874        0.752962
# 2               317   0.698413  0.293987        0.785878        0.778436
# 3               282   0.698745  0.371938        0.795276        0.790284
# 4               252   0.693662  0.438753        0.803912        0.799171
# 5               252   0.681661  0.438753        0.812294        0.796209
# 6               236   0.671924  0.474388        0.822962        0.798578
# 7               234   0.655488  0.478842        0.838456        0.794431
# 8               226   0.655882  0.496659        0.859030        0.796801
# 9               224   0.644699  0.501114        0.887224        0.793839
# 10              222   0.639437  0.505568        0.918974        0.792654
# 11              227   0.628895  0.494432        0.953264        0.787915
# 12              222   0.623626  0.505568        0.975616        0.787322
# 13              222   0.618529  0.505568        0.987300        0.785545
# 14              222   0.618529  0.505568        0.993904        0.785545
# 15              228   0.603825  0.492205        0.996444        0.779028
# 16              229   0.607735  0.489978        0.996952        0.780213
# 17              226   0.607629  0.496659        0.997968        0.780806
# 18              226   0.629944  0.496659        0.997968        0.788507
# 19              224   0.623269  0.501114        0.997968        0.786730
# 20              226   0.617729  0.496659        0.997968        0.784360
# 21              231   0.612360  0.485523        0.997968        0.781398
# 22              233   0.613636  0.481069        0.997968        0.781398
# 23              233   0.600000  0.481069        0.997968        0.776659
# 24              231   0.600551  0.485523        0.997968        0.777251
#
#     Score Difference
# 0           0.000311
# 1           0.000911
# 2           0.007442
# 3           0.004991
# 4           0.004741
# 5           0.016085
# 6           0.024383
# 7           0.044024
# 8           0.062229
# 9           0.093385
# 10          0.126320
# 11          0.165349
# 12          0.188294
# 13          0.201755
# 14          0.208359
# 15          0.217416
# 16          0.216739
# 17          0.217162
# 18          0.209461
# 19          0.211238
# 20          0.213608
# 21          0.216570
# 22          0.216570
# 23          0.221309
# 24          0.220717

# %% [markdown]
# ### Key Takeaways:
# The first thing I noticed is that after about a max_depth of 10, the classifier becomes a bit too overfit and the validate accuracy begins dropping. So far, the best performing model was the one with only a max_depth of 5, and it is almost perfectly fit with very little difference between the training score and validate score.
#
# ### Next:
# Next, I would like to loop through the first 10 models, but only change the min_samples_leaf.

# %%
model_dicts = []

for num in range(1, 11):
    #Now create a new loop that runs through different min_samples_leaf values
    for val in range(1, 26):
        #Instantiate new model
        clf = RandomForestClassifier(random_state = 123, max_depth = num, min_samples_leaf = val)
    
        #Fit the model
        clf.fit(X_train, y_train)
    
        #Score the model on training data
        train_score = clf.score(X_train, y_train)
    
        #Make predictions on validate data to use in confusion matrix
        clf_preds = clf.predict(X_validate)
        
        #Use confusion matrix to find TP, FP, TN, FN
        tp = confusion_matrix(y_validate, clf_preds)[1][1]
        fp = confusion_matrix(y_validate, clf_preds)[0][1]
        tn = confusion_matrix(y_validate, clf_preds)[0][0]
        fn = confusion_matrix(y_validate, clf_preds)[1][0]
        #Score the model on validate data
        validate_score = clf.score(X_validate, y_validate)
    
        #Create a dictionary for model values
        output = {
            'max_depth':num,
            'min_samples_leaf': val,
            'True Positves': tp,
            'False Positives': fp,
            'True Negatives': tn,
            'False Negatvies': fn,
            'Precision': tp / (tp + fp),
            'Recall': tp / (tp + fn),
            'Training Score': train_score,
            'Validate Score': validate_score,
            'Score Difference': train_score - validate_score
        }
        
        model_dicts.append(output)

models = pd.DataFrame(model_dicts)
# Out:
# <ipython-input-9-8f8538f367b6>:34: RuntimeWarning: invalid value encountered in long_scalars
#   'Precision': tp / (tp + fp),
# <ipython-input-9-8f8538f367b6>:34: RuntimeWarning: invalid value encountered in long_scalars
#   'Precision': tp / (tp + fp),
# <ipython-input-9-8f8538f367b6>:34: RuntimeWarning: invalid value encountered in long_scalars
#   'Precision': tp / (tp + fp),
# <ipython-input-9-8f8538f367b6>:34: RuntimeWarning: invalid value encountered in long_scalars
#   'Precision': tp / (tp + fp),
# <ipython-input-9-8f8538f367b6>:34: RuntimeWarning: invalid value encountered in long_scalars
#   'Precision': tp / (tp + fp),
# <ipython-input-9-8f8538f367b6>:34: RuntimeWarning: invalid value encountered in long_scalars
#   'Precision': tp / (tp + fp),
# <ipython-input-9-8f8538f367b6>:34: RuntimeWarning: invalid value encountered in long_scalars
#   'Precision': tp / (tp + fp),
# <ipython-input-9-8f8538f367b6>:34: RuntimeWarning: invalid value encountered in long_scalars
#   'Precision': tp / (tp + fp),
# <ipython-input-9-8f8538f367b6>:34: RuntimeWarning: invalid value encountered in long_scalars
#   'Precision': tp / (tp + fp),
# <ipython-input-9-8f8538f367b6>:34: RuntimeWarning: invalid value encountered in long_scalars
#   'Precision': tp / (tp + fp),
# <ipython-input-9-8f8538f367b6>:34: RuntimeWarning: invalid value encountered in long_scalars
#   'Precision': tp / (tp + fp),
# <ipython-input-9-8f8538f367b6>:34: RuntimeWarning: invalid value encountered in long_scalars
#   'Precision': tp / (tp + fp),
# <ipython-input-9-8f8538f367b6>:34: RuntimeWarning: invalid value encountered in long_scalars
#   'Precision': tp / (tp + fp),
# <ipython-input-9-8f8538f367b6>:34: RuntimeWarning: invalid value encountered in long_scalars
#   'Precision': tp / (tp + fp),
# <ipython-input-9-8f8538f367b6>:34: RuntimeWarning: invalid value encountered in long_scalars
#   'Precision': tp / (tp + fp),
# <ipython-input-9-8f8538f367b6>:34: RuntimeWarning: invalid value encountered in long_scalars
#   'Precision': tp / (tp + fp),
# <ipython-input-9-8f8538f367b6>:34: RuntimeWarning: invalid value encountered in long_scalars
#   'Precision': tp / (tp + fp),
# <ipython-input-9-8f8538f367b6>:34: RuntimeWarning: invalid value encountered in long_scalars
#   'Precision': tp / (tp + fp),
# <ipython-input-9-8f8538f367b6>:34: RuntimeWarning: invalid value encountered in long_scalars
#   'Precision': tp / (tp + fp),
# <ipython-input-9-8f8538f367b6>:34: RuntimeWarning: invalid value encountered in long_scalars
#   'Precision': tp / (tp + fp),
# <ipython-input-9-8f8538f367b6>:34: RuntimeWarning: invalid value encountered in long_scalars
#   'Precision': tp / (tp + fp),
# <ipython-input-9-8f8538f367b6>:34: RuntimeWarning: invalid value encountered in long_scalars
#   'Precision': tp / (tp + fp),
# <ipython-input-9-8f8538f367b6>:34: RuntimeWarning: invalid value encountered in long_scalars
#   'Precision': tp / (tp + fp),
# <ipython-input-9-8f8538f367b6>:34: RuntimeWarning: invalid value encountered in long_scalars
#   'Precision': tp / (tp + fp),
# <ipython-input-9-8f8538f367b6>:34: RuntimeWarning: invalid value encountered in long_scalars
#   'Precision': tp / (tp + fp),

# %%
models
# Out:
#      max_depth  min_samples_leaf  True Positves  False Positives  \
# 0            1                 1              0                0
# 1            1                 2              0                0
# 2            1                 3              0                0
# 3            1                 4              0                0
# 4            1                 5              0                0
# ..         ...               ...            ...              ...
# 245         10                21            215              109
# 246         10                22            221              108
# 247         10                23            218              105
# 248         10                24            215              106
# 249         10                25            216              104
#
#      True Negatives  False Negatvies  Precision    Recall  Training Score  \
# 0              1239              449        NaN  0.000000        0.734315
# 1              1239              449        NaN  0.000000        0.734315
# 2              1239              449        NaN  0.000000        0.734315
# 3              1239              449        NaN  0.000000        0.734315
# 4              1239              449        NaN  0.000000        0.734315
# ..              ...              ...        ...       ...             ...
# 245            1130              234   0.663580  0.478842        0.817628
# 246            1131              228   0.671733  0.492205        0.817374
# 247            1134              231   0.674923  0.485523        0.817882
# 248            1133              234   0.669782  0.478842        0.814834
# 249            1135              233   0.675000  0.481069        0.815850
#
#      Validate Score  Score Difference
# 0          0.734005          0.000311
# 1          0.734005          0.000311
# 2          0.734005          0.000311
# 3          0.734005          0.000311
# 4          0.734005          0.000311
# ..              ...               ...
# 245        0.796801          0.020827
# 246        0.800948          0.016426
# 247        0.800948          0.016934
# 248        0.798578          0.016255
# 249        0.800355          0.015494
#
# [250 rows x 11 columns]

# %%
models[models['Validate Score'] > 0.80]
# Out:
#      max_depth  min_samples_leaf  True Positves  False Positives  \
# 114          5                15            201               86
# 154          7                 5            220              107
# 159          7                10            218              103
# 163          7                14            223              107
# 164          7                15            220              107
# 172          7                23            214              100
# 174          7                25            216              104
# 185          8                11            222              105
# 186          8                12            223              108
# 192          8                18            222              110
# 195          8                21            218              106
# 199          8                25            217              105
# 209          9                10            223              108
# 213          9                14            222              108
# 219          9                20            220              107
# 220          9                21            221              107
# 229         10                 5            232              118
# 230         10                 6            229              117
# 232         10                 8            224              111
# 238         10                14            221              109
# 240         10                16            222              109
# 243         10                19            220              105
# 246         10                22            221              108
# 247         10                23            218              105
# 249         10                25            216              104
#
#      True Negatives  False Negatvies  Precision    Recall  Training Score  \
# 114            1153              248   0.700348  0.447661        0.801626
# 154            1132              229   0.672783  0.489978        0.820676
# 159            1136              231   0.679128  0.485523        0.818898
# 163            1132              226   0.675758  0.496659        0.816866
# 164            1132              229   0.672783  0.489978        0.815342
# 172            1139              235   0.681529  0.476615        0.816612
# 174            1135              233   0.675000  0.481069        0.812548
# 185            1134              227   0.678899  0.494432        0.818898
# 186            1131              226   0.673716  0.496659        0.821438
# 192            1129              227   0.668675  0.494432        0.817628
# 195            1133              231   0.672840  0.485523        0.814326
# 199            1134              232   0.673913  0.483296        0.813564
# 209            1131              226   0.673716  0.496659        0.826264
# 213            1131              227   0.672727  0.494432        0.822708
# 219            1132              229   0.672783  0.489978        0.815850
# 220            1132              228   0.673780  0.492205        0.818390
# 229            1121              217   0.662857  0.516704        0.844552
# 230            1122              220   0.661850  0.510022        0.839472
# 232            1128              225   0.668657  0.498886        0.835916
# 238            1130              228   0.669697  0.492205        0.824994
# 240            1130              227   0.670695  0.494432        0.823724
# 243            1134              229   0.676923  0.489978        0.819406
# 246            1131              228   0.671733  0.492205        0.817374
# 247            1134              231   0.674923  0.485523        0.817882
# 249            1135              233   0.675000  0.481069        0.815850
#
#      Validate Score  Score Difference
# 114        0.802133         -0.000507
# 154        0.800948          0.019728
# 159        0.802133          0.016765
# 163        0.802725          0.014141
# 164        0.800948          0.014394
# 172        0.801540          0.015071
# 174        0.800355          0.012192
# 185        0.803318          0.015580
# 186        0.802133          0.019305
# 192        0.800355          0.017272
# 195        0.800355          0.013970
# 199        0.800355          0.013208
# 209        0.802133          0.024131
# 213        0.801540          0.021167
# 219        0.800948          0.014902
# 220        0.801540          0.016849
# 229        0.801540          0.043011
# 230        0.800355          0.039116
# 232        0.800948          0.034968
# 238        0.800355          0.024638
# 240        0.800948          0.022776
# 243        0.802133          0.017273
# 246        0.800948          0.016426
# 247        0.800948          0.016934
# 249        0.800355          0.015494

# %% [markdown]
# ### Key Takeaways:
# Despite changing the number of min_samples_leaf, there were no major improvements in performance. However, the model with max_depth of 5 had a slight performance boost when min_samples_leaf was set to 15. I will use this model for my MVP.

# %% [markdown]
# ### Next:
# Next, I will score the chosen model on the test data set.

# %%
#Instantiate the model
clf = RandomForestClassifier(random_state = 123, max_depth = 5, min_samples_leaf = 15)

#Fit the model
clf.fit(X_train, y_train)

#Score the model on training data
train_score = clf.score(X_train, y_train)

#Score the model on validate data
validate_score = clf.score(X_validate, y_validate)

#Score the model on test data
test_score = clf.score(X_test, y_test)

#Make predictions on test data to use in confusion matrix
clf_preds = clf.predict(X_test)

#Use confusion matrix to find TP, FP, TN, FN
tp = confusion_matrix(y_test, clf_preds)[1][1]
fp = confusion_matrix(y_test, clf_preds)[0][1]
tn = confusion_matrix(y_test, clf_preds)[0][0]
fn = confusion_matrix(y_test, clf_preds)[1][0]


#Create a dictionary for model values
output = {
    'max_depth':5,
    'min_samples_leaf': 15,
    'True Positves': tp,
    'False Positives': fp,
    'True Negatives': tn,
    'False Negatvies': fn,
    'Precision': tp / (tp + fp),
    'Recall': tp / (tp + fn),
    'Training Score': train_score,
    'Validate Score': validate_score,
    'Test Score': test_score,
    'Score Difference': validate_score - test_score
}

test_set = []
test_set.append(output)

test_model = pd.DataFrame(test_set)
test_model
# Out:
#    max_depth  min_samples_leaf  True Positves  False Positives  \
# 0          5                15            171               77
#
#    True Negatives  False Negatvies  Precision    Recall  Training Score  \
# 0             956              203   0.689516  0.457219        0.801626
#
#    Validate Score  Test Score  Score Difference
# 0        0.802133    0.800995          0.001138

# %% [markdown]
# ### Next:
# I will create a function to run these models and print out the results in a similar format. However, to limit the number of rows displaying, I will only show those that have a validate score higher than .80. I will save this function in model.py.

# %% [markdown]
# ### Function is complete.
#
# ### Next:
# I will create a function that creates a df containing customer_id, churn probability, and churn prediction for the test data set.

# %%
#Since I need customer_id, I must get it from the explore version of test.
train_explore, validate_explore, test_explore = prepare.prep_without_encoding(telco)
test_explore
# Out:
#      customer_id  gender senior_citizen partner dependents  tenure  \
# 2897  0864-FVJNJ  Female             No     Yes        Yes      64
# 6407  6870-ECSHE  Female             No      No         No       2
# 6272  3452-FLHYD    Male             No     Yes         No      25
# 5638  1927-QEWMY  Female             No     Yes         No      72
# 903   4872-VXRIL    Male             No      No         No      56
# ...          ...     ...            ...     ...        ...     ...
# 1524  2833-SLKDQ    Male             No      No         No       1
# 3536  0644-OQMDK    Male            Yes      No         No       4
# 3927  2632-UCGVD    Male            Yes     Yes         No      66
# 263   4671-VJLCL  Female             No      No         No      63
# 3245  7080-TNUWP    Male             No     Yes         No      70
#
#      phone_service multiple_lines      online_security        online_backup  \
# 2897           Yes            Yes                  Yes                  Yes
# 6407           Yes             No  No internet service  No internet service
# 6272           Yes             No  No internet service  No internet service
# 5638           Yes             No  No internet service  No internet service
# 903            Yes            Yes                  Yes                  Yes
# ...            ...            ...                  ...                  ...
# 1524           Yes             No                   No                   No
# 3536           Yes             No                   No                   No
# 3927           Yes            Yes                   No                   No
# 263            Yes            Yes                  Yes                  Yes
# 3245           Yes            Yes                   No                  Yes
#
#       ...         tech_support         streaming_tv     streaming_movies  \
# 2897  ...                  Yes                  Yes                  Yes
# 6407  ...  No internet service  No internet service  No internet service
# 6272  ...  No internet service  No internet service  No internet service
# 5638  ...  No internet service  No internet service  No internet service
# 903   ...                  Yes                   No                   No
# ...   ...                  ...                  ...                  ...
# 1524  ...                   No                   No                   No
# 3536  ...                   No                   No                   No
# 3927  ...                  Yes                  Yes                  Yes
# 263   ...                  Yes                  Yes                   No
# 3245  ...                   No                  Yes                   No
#
#      paperless_billing monthly_charges  total_charges  churn   contract_type  \
# 2897                No          113.35        7222.75     No        One year
# 6407                No           20.45          34.80     No        One year
# 6272               Yes           20.95         495.15     No        One year
# 5638                No           20.50        1502.25     No        Two year
# 903                Yes           64.65        3665.55     No        One year
# ...                ...             ...            ...    ...             ...
# 1524                No           45.05          45.05    Yes  Month-to-month
# 3536               Yes           70.65         293.85     No  Month-to-month
# 3927               Yes          100.05        6871.90    Yes  Month-to-month
# 263                Yes           79.85        4861.45     No        Two year
# 3245               Yes           95.00        6602.90     No        One year
#
#      internet_service_type               payment_type
# 2897           Fiber optic           Electronic check
# 6407                  None               Mailed check
# 6272                  None  Bank transfer (automatic)
# 5638                  None    Credit card (automatic)
# 903                    DSL  Bank transfer (automatic)
# ...                    ...                        ...
# 1524                   DSL               Mailed check
# 3536           Fiber optic           Electronic check
# 3927           Fiber optic    Credit card (automatic)
# 263                    DSL    Credit card (automatic)
# 3245           Fiber optic  Bank transfer (automatic)
#
# [1407 rows x 21 columns]

# %%
#Build a df containing churn proba
churn_proba = clf.predict_proba(X_test)
proba_df = pd.DataFrame(churn_proba, columns = ['probability_not_churned', 'probability_churned'])
proba_df
# Out:
#       probability_not_churned  probability_churned
# 0                    0.789310             0.210690
# 1                    0.891388             0.108612
# 2                    0.953725             0.046275
# 3                    0.987700             0.012300
# 4                    0.896498             0.103502
# ...                       ...                  ...
# 1402                 0.510527             0.489473
# 1403                 0.362178             0.637822
# 1404                 0.741420             0.258580
# 1405                 0.941308             0.058692
# 1406                 0.778171             0.221829
#
# [1407 rows x 2 columns]

# %%
#Add each column one at a time
reset_test = test_explore.reset_index()
reset_test['probability_not_churned'] = proba_df['probability_not_churned']
reset_test['probability_churned'] = proba_df['probability_churned']
reset_test
# Out:
#       index customer_id  gender senior_citizen partner dependents  tenure  \
# 0      2897  0864-FVJNJ  Female             No     Yes        Yes      64
# 1      6407  6870-ECSHE  Female             No      No         No       2
# 2      6272  3452-FLHYD    Male             No     Yes         No      25
# 3      5638  1927-QEWMY  Female             No     Yes         No      72
# 4       903  4872-VXRIL    Male             No      No         No      56
# ...     ...         ...     ...            ...     ...        ...     ...
# 1402   1524  2833-SLKDQ    Male             No      No         No       1
# 1403   3536  0644-OQMDK    Male            Yes      No         No       4
# 1404   3927  2632-UCGVD    Male            Yes     Yes         No      66
# 1405    263  4671-VJLCL  Female             No      No         No      63
# 1406   3245  7080-TNUWP    Male             No     Yes         No      70
#
#      phone_service multiple_lines      online_security  ...  \
# 0              Yes            Yes                  Yes  ...
# 1              Yes             No  No internet service  ...
# 2              Yes             No  No internet service  ...
# 3              Yes             No  No internet service  ...
# 4              Yes            Yes                  Yes  ...
# ...            ...            ...                  ...  ...
# 1402           Yes             No                   No  ...
# 1403           Yes             No                   No  ...
# 1404           Yes            Yes                   No  ...
# 1405           Yes            Yes                  Yes  ...
# 1406           Yes            Yes                   No  ...
#
#          streaming_movies paperless_billing monthly_charges total_charges  \
# 0                     Yes                No          113.35       7222.75
# 1     No internet service                No           20.45         34.80
# 2     No internet service               Yes           20.95        495.15
# 3     No internet service                No           20.50       1502.25
# 4                      No               Yes           64.65       3665.55
# ...                   ...               ...             ...           ...
# 1402                   No                No           45.05         45.05
# 1403                   No               Yes           70.65        293.85
# 1404                  Yes               Yes          100.05       6871.90
# 1405                   No               Yes           79.85       4861.45
# 1406                   No               Yes           95.00       6602.90
#
#      churn   contract_type  internet_service_type               payment_type  \
# 0       No        One year            Fiber optic           Electronic check
# 1       No        One year                   None               Mailed check
# 2       No        One year                   None  Bank transfer (automatic)
# 3       No        Two year                   None    Credit card (automatic)
# 4       No        One year                    DSL  Bank transfer (automatic)
# ...    ...             ...                    ...                        ...
# 1402   Yes  Month-to-month                    DSL               Mailed check
# 1403    No  Month-to-month            Fiber optic           Electronic check
# 1404   Yes  Month-to-month            Fiber optic    Credit card (automatic)
# 1405    No        Two year                    DSL    Credit card (automatic)
# 1406    No        One year            Fiber optic  Bank transfer (automatic)
#
#      probability_not_churned probability_churned
# 0                   0.789310            0.210690
# 1                   0.891388            0.108612
# 2                   0.953725            0.046275
# 3                   0.987700            0.012300
# 4                   0.896498            0.103502
# ...                      ...                 ...
# 1402                0.510527            0.489473
# 1403                0.362178            0.637822
# 1404                0.741420            0.258580
# 1405                0.941308            0.058692
# 1406                0.778171            0.221829
#
# [1407 rows x 24 columns]

# %%
#Now add the test predictions
reset_test['predicted'] = clf_preds
reset_test
# Out:
#       index customer_id  gender senior_citizen partner dependents  tenure  \
# 0      2897  0864-FVJNJ  Female             No     Yes        Yes      64
# 1      6407  6870-ECSHE  Female             No      No         No       2
# 2      6272  3452-FLHYD    Male             No     Yes         No      25
# 3      5638  1927-QEWMY  Female             No     Yes         No      72
# 4       903  4872-VXRIL    Male             No      No         No      56
# ...     ...         ...     ...            ...     ...        ...     ...
# 1402   1524  2833-SLKDQ    Male             No      No         No       1
# 1403   3536  0644-OQMDK    Male            Yes      No         No       4
# 1404   3927  2632-UCGVD    Male            Yes     Yes         No      66
# 1405    263  4671-VJLCL  Female             No      No         No      63
# 1406   3245  7080-TNUWP    Male             No     Yes         No      70
#
#      phone_service multiple_lines      online_security  ... paperless_billing  \
# 0              Yes            Yes                  Yes  ...                No
# 1              Yes             No  No internet service  ...                No
# 2              Yes             No  No internet service  ...               Yes
# 3              Yes             No  No internet service  ...                No
# 4              Yes            Yes                  Yes  ...               Yes
# ...            ...            ...                  ...  ...               ...
# 1402           Yes             No                   No  ...                No
# 1403           Yes             No                   No  ...               Yes
# 1404           Yes            Yes                   No  ...               Yes
# 1405           Yes            Yes                  Yes  ...               Yes
# 1406           Yes            Yes                   No  ...               Yes
#
#      monthly_charges total_charges churn   contract_type  \
# 0             113.35       7222.75    No        One year
# 1              20.45         34.80    No        One year
# 2              20.95        495.15    No        One year
# 3              20.50       1502.25    No        Two year
# 4              64.65       3665.55    No        One year
# ...              ...           ...   ...             ...
# 1402           45.05         45.05   Yes  Month-to-month
# 1403           70.65        293.85    No  Month-to-month
# 1404          100.05       6871.90   Yes  Month-to-month
# 1405           79.85       4861.45    No        Two year
# 1406           95.00       6602.90    No        One year
#
#      internet_service_type               payment_type  \
# 0              Fiber optic           Electronic check
# 1                     None               Mailed check
# 2                     None  Bank transfer (automatic)
# 3                     None    Credit card (automatic)
# 4                      DSL  Bank transfer (automatic)
# ...                    ...                        ...
# 1402                   DSL               Mailed check
# 1403           Fiber optic           Electronic check
# 1404           Fiber optic    Credit card (automatic)
# 1405                   DSL    Credit card (automatic)
# 1406           Fiber optic  Bank transfer (automatic)
#
#       probability_not_churned probability_churned predicted
# 0                    0.789310            0.210690         0
# 1                    0.891388            0.108612         0
# 2                    0.953725            0.046275         0
# 3                    0.987700            0.012300         0
# 4                    0.896498            0.103502         0
# ...                       ...                 ...       ...
# 1402                 0.510527            0.489473         0
# 1403                 0.362178            0.637822         1
# 1404                 0.741420            0.258580         0
# 1405                 0.941308            0.058692         0
# 1406                 0.778171            0.221829         0
#
# [1407 rows x 25 columns]

# %%
#Now select only the columns required in a new data frame.
csv_df = reset_test[['customer_id', 'probability_not_churned', 'probability_churned', 'predicted']]
csv_df
# Out:
#      customer_id  probability_not_churned  probability_churned  predicted
# 0     0864-FVJNJ                 0.789310             0.210690          0
# 1     6870-ECSHE                 0.891388             0.108612          0
# 2     3452-FLHYD                 0.953725             0.046275          0
# 3     1927-QEWMY                 0.987700             0.012300          0
# 4     4872-VXRIL                 0.896498             0.103502          0
# ...          ...                      ...                  ...        ...
# 1402  2833-SLKDQ                 0.510527             0.489473          0
# 1403  0644-OQMDK                 0.362178             0.637822          1
# 1404  2632-UCGVD                 0.741420             0.258580          0
# 1405  4671-VJLCL                 0.941308             0.058692          0
# 1406  7080-TNUWP                 0.778171             0.221829          0
#
# [1407 rows x 4 columns]

# %% [markdown]
# ### Final Step:
# The last step is to take this df and convert it to a csv file. This is easy to do with pd.to_csv(). I won't do it here, only in the final report.
